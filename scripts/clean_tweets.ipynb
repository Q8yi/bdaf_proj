# %%
import pandas as pd
import numpy as np

# %%
#X usernames of influential people in blockchains
influential = ['realDonaldTrump', 'elonmusk', 'brian_armstrong', 'ZssBecker', 'Barry Silbert', 'CathieDWood', 'IOHK_Charles'\
               'bgarlinghouse', 'saylor', 'SenLummis', 'shayne_coplan',\
               'Vivekramaswamy', 'JohnEDeaton1', 'VitalikButerin', 'SatoshiLite',\
               'adam3us', 'cz_binance', 'aantonop', 'APompliano', 'balajis', \
               'ErikVoorhees', 'pmarca', 'rogerkver', 'cdixon', 'RyanSAdams', 'TrustlessState', \
                                   #uniswap inventor
               'StaniKulechov', 'haydenzadams', 'kaiynne', 'CamiRusso', \
               'stablekwon', 'gavofyork', 'IOHK_Charles', \

               'filbfilb', \
               'farokh', 'BennyGiang', 'elliotrades', 'kevinrose', 'steveaoki',\
                'Excellion', 'JackMallers', 'starkness', 'paoloardoino',\

               'jihanwu', 'BarrySilbert', 'jack', 'RaoulGMI', 'kris', 'SBF_FTX','Melt_Dem', 'dannyryan',\
               'sergeynazarov', 'gavofyork', 'CaitlinLong_', 'CathieDWood', 'chamath', 'tyler', 'ethereumJoseph', \
               'rleshner', 'jerallaire', 'cameron', 'JedMcCaleb', 'AndreCronjeTech', 'pmarca', 'twobitidiot', \
               'OneMorePeter', 'gavinandresen', 'kaiynne', 'spair', 'sammcingvale', 'bobbyong', 'polychain', \
               'jespow', 'RuneKek', 'bengoertzel', 'dan_pantera', 'ptj_official', 'nejc_kodric', 'ssrinawakoon', \
               'brianbrooksocc', 'SatoshiLite', 'cdixon', 'NickSzabo4', 'lopp', 'VinnyLingham', 'CharlieShrem', \
               'timdraper', 'laurashin', 'dahongfei', 'AriDavidPaul', 'sallyeaves', 'cryptomanran', \
               'fehrsam', 'el33th4xor', 'bobbyclee', 'ljxie', 'yuzokano', 'AriannaSimpson', 'AriannaSimpson', 'muneeb',\
               'domschiener', 'cryptocoley', 'katie_haun', 'jbrukh', 'mikebelshe', 'matthewroszak', 'pbartstephens', \
               'joshfraser', 'ericlarch'
              ]

'''
'scottmelker', 'woonomic', '100trillionUSD',
               'PeterLBrandt', 'TheCryptoLark', 'intocryptoverse', 'rektcapital', 'crypto_birb',\
               'CryptoMichNL', 'cointradernik', 'Pentosh1', 'Trader1SZ', 'CryptoKaleo', \
               'CarpeNoctom', 'BigCheds', 'IncomeSharks', 'CryptoCred', 'ColdBloodShill', 'AltcoinPsycho'

'''
# Out:
# "\n'scottmelker', 'woonomic', '100trillionUSD',\n               'PeterLBrandt', 'TheCryptoLark', 'intocryptoverse', 'rektcapital', 'crypto_birb',               'CryptoMichNL', 'cointradernik', 'Pentosh1', 'Trader1SZ', 'CryptoKaleo',                'CarpeNoctom', 'BigCheds', 'IncomeSharks', 'CryptoCred', 'ColdBloodShill', 'AltcoinPsycho'\n\n"

# %%
def check_influencer(df, col_name):
    df['influencer'] = df[col_name].isin(influential)
    influential_tweets = df[df['influencer'] == True]
    print(df['influencer'].value_counts())

    return influential_tweets, df

# %%
bitcoin_tweets = pd.read_csv("../datasets/tweets/original/Bitcoin_tweets.csv")

# %%
influential_tweets2, bitcoin_tweets = check_influencer(bitcoin_tweets, 'user_name')
#influential_tweets2
influential_tweets2.to_csv("bitcoin_tweets.filtered.csv")
# Out:
# influencer
# False    95762357
# True          111
# Name: count, dtype: int64
#         user_name user_location                        user_description  \
# 51132        jack           NaN                                     NaN
# 52599        jack           NaN                                     NaN
# 52808        jack           NaN                                     NaN
# 52811        jack           NaN                                     NaN
# 52814        jack           NaN                                     NaN
# ...           ...           ...                                     ...
# 4041763      jack           NaN                                     NaN
# 4366631      jack            pa  IFBB Pro. Award Winning Author. Gamer.
# 4459758      kris    Texas, USA                          proverbs 11:25
# 4471987      jack           NaN                                     NaN
# 4529196      jack   To The Moon                       (IDO)Airdrop &IDO
#
# ...

# %%
influential_tweets2.to_csv("bitcoin_tweets.filtered.csv")

# %%
Bitcoin_tweets_dataset_2 = pd.read_csv("../datasets/tweets/original/Bitcoin_tweets_dataset_2.csv", engine='python')

# %%
influential_tweets3, Bitcoin_tweets_dataset_2 = check_influencer(Bitcoin_tweets_dataset_2, 'user_name')
influential_tweets3
# Out:
# influencer
# False    174397
# Name: count, dtype: int64
# Empty DataFrame
# Columns: [user_name, user_location, user_description, user_created, user_followers, user_friends, user_favourites, user_verified, date, text, hashtags, source, is_retweet, influencer]
# Index: []

# %%
Blochchain_tweets_dataset_2 = pd.read_csv("../datasets/tweets/original/blockchain_tweets.csv", engine='python')
Blochchain_tweets_dataset_2
# Out:
#                                 user_name   user_location  \
# 0                               Blockwork             NaN
# 1                                  Rib-It             NaN
# 2     ❤️LacedWhales (CARDANO POOL: PEACE)             NaN
# 3                       Wiscobus Ntukuyoh          Lagos
# 4                                  Rib-It             NaN
# ...                                   ...             ...
# 9995                     Ucu Jaenurisalah             NaN
# 9996  ❤️LacedWhales (CARDANO POOL: PEACE)             NaN
# 9997                   Towolawi Oluwaseun  Lagos, Nigeria
# 9998                           $CRYPTOWOO   United States
# 9999  ❤️LacedWhales (CARDANO POOL: PEACE)             NaN
#
#                                        user_description  \
# 0     Find a job in blockchain: https://t.co/7X6K6WK...
# 1     🐸 RibIt 2021 YOU are the foundation of our cre...
# 2     1M+ $ADA whale txs laced with ❤️ from La @Reps...
# ...

# %%
influential_tweets4, Blochchain_tweets_dataset_2 = check_influencer(Blochchain_tweets_dataset_2, 'user_name')
# Out:
# influencer
# False    10000
# Name: count, dtype: int64

# %%
influential_tweets4
# Out:
# Empty DataFrame
# Columns: [user_name, user_location, user_description, user_created, user_followers, user_friends, user_favourites, user_verified, date, text, hashtags, source, is_retweet, influencer]
# Index: []

# %%
crypto_tweets_dataset = pd.read_csv("../datasets/tweets/original/crypto_tweets.csv", engine='python')
crypto_tweets_dataset
# Out:
#      Unnamed: 0       user_name                       date  likes  retweets  \
# 0             0     aussieruled  2022-10-31 01:08:24+00:00    512         9
# 1             1   OlimpioCrypto  2022-10-30 14:38:03+00:00   1159       314
# 2             2         binance  2022-10-30 07:00:00+00:00    977       286
# 3             3  SilvermanJacob  2022-10-29 18:27:04+00:00    322        50
# 4             4         romoolo  2022-10-29 11:13:00+00:00    778        34
# ..          ...             ...                        ...    ...       ...
# 395         395   coryklippsten  2022-05-13 15:37:14+00:00    402        46
# 396         396     oclocal_ami  2022-05-13 14:04:52+00:00    428       165
# 397         397       BriannaWu  2022-05-13 12:35:49+00:00    852        48
# 398         398     Being_Humor  2022-05-13 07:28:36+00:00   1401       685
# 399         399       IcedKnife  2022-05-13 06:28:18+00:00    420        51
#
# ...

# %%
influential_tweets5, crypto_tweets_dataset = check_influencer(crypto_tweets_dataset, 'user_name')
influential_tweets5
influential_tweets5.to_csv("crpyto_tweets_filtered.csv")
# Out:
# influencer
# False    388
# True      12
# Name: count, dtype: int64

# %%
crypto_tweets_3000 = pd.read_csv("../datasets/tweets/original/crypto_tweets_3000.csv", engine='python')


doge_tweets = pd.read_csv("../datasets/tweets/original/doge_tweets.csv", engine='python')
doge_tweets, crypto_tweets_3000
# Out:
# (        Unnamed: 0                   id      conversation_id  \
#  0                0  1387557236457627653  1387557236457627653
#  1                1  1387557180862259206  1387488165175382016
#  2                2  1387557162222768130  1387330273109549058
#  3                3  1387557160708608002  1387557160708608002
#  4                4  1387557153976819715  1387557153976819715
#  ...            ...                  ...                  ...
#  3421380    3421340  1344795651448602624  1344795651448602624
#  3421381    3421341  1344795620201164800  1344795620201164800
#  3421382    3421342  1344795594636849155  1344793981201375233
#  3421383    3421343  1344795507881893888  1344795507881893888
#  3421384    3421344  1344795477296996352  1344795477296996352
#
#                          created_at        date      time  timezone  \
#  0        2021-04-28 23:59:59+00:00  2021-04-28  16:59:59    -700.0
#  1        2021-04-28 23:59:46+00:00  2021-04-28  16:59:46    -700.0
# ...

# %%
influential_tweets6, crypto_tweets_3000 = check_influencer(crypto_tweets_3000, 'user_name')
influential_tweets7, doge_tweets = check_influencer(doge_tweets, 'username')
influential_tweets6, influential_tweets7
# Out:
# influencer
# False    2403
# True      316
# Name: count, dtype: int64
# influencer
# False    3421273
# True         112
# Name: count, dtype: int64
# (      Unnamed: 0       user_name                       date  likes  retweets  \
#  2              2  VitalikButerin  2022-10-30 03:17:33+00:00  13050      1484
#  5              5      cz_binance  2022-10-29 07:17:00+00:00  37662      5898
#  12            12  VitalikButerin  2022-10-28 01:28:29+00:00   6066       833
#  25            25        Melt_Dem  2022-10-25 00:49:56+00:00   3106       445
#  28            28      cz_binance  2022-10-24 15:17:41+00:00  12120      2350
#  ...          ...             ...                        ...    ...       ...
#  2705        2705       ZssBecker  2021-11-01 19:15:48+00:00   4361       601
#  2707        2707        elonmusk  2021-11-01 18:45:26+00:00  19095      2764
#  2708        2708     elliotrades  2021-11-01 17:30:19+00:00   3634       412
# ...

# %%
influential_tweets6.to_csv("crypto_tweets_3000_filtered.csv"), influential_tweets7.to_csv("doge_tweets_filtered.csv")

# %%
Ethereum_tweets = pd.read_csv("../datasets/tweets/original/Ethereum_tweets.csv", engine='python')
Ethereum_tweets
# Out:
#                        user_name           user_location  \
# 0     #1 Crypto Currency TRADING                     NaN
# 1                         Reyrey            Kuala Lumpur
# 2                    akter jahan                     NaN
# 3                          riyan                     NaN
# 4               Michelle Eriksen                     NaN
# ...                          ...                     ...
# 9995             DAIANA LAZZARIN               Metaverse
# 9996               frieslips.nft   Yogyakarta, Indonesia
# 9997                       dave.                     NaN
# 9998             Crypto Whispers                     NaN
# 9999     SorareBot by SorareData  https://soraredata.com
#
#                                        user_description  \
# 0     Profit thought trading, Learn , Trade & Earn💲....
# 1     Artist | NFT Broker & Collector for AnideaNFT ...
# 2                                                   NaN
# ...

# %%
influential_tweets8, Ethereum_tweets = check_influencer(Ethereum_tweets, 'user_name')
influential_tweets8.to_csv("Ethereum_tweets_filtered.csv")
# Out:
# influencer
# False    9999
# True        1
# Name: count, dtype: int64

# %%
tweet_2024 = pd.read_parquet("../datasets/tweets/original/tweet_2024.parquet")
tweet_2024["user_name"] = tweet_2024["Asset Destination"].str.split("/").str[3]

# %%
tweet_2024["user_name"]
# Out:
# 0              elonmusk
# 1              elonmusk
# 2              elonmusk
# 3              elonmusk
# 4              elonmusk
#               ...
# 27618           HagovQA
# 27619     joacotossello
# 27620    AlexBaca392340
# 27621        uliisesten
# 27622           HagovQA
# Name: user_name, Length: 27623, dtype: object

# %%
influential_tweets9, tweet_2024 = check_influencer(tweet_2024, 'user_name')
influential_tweets9
influential_tweets9.to_csv("tweet_2024_filtered.csv")
# Out:
# influencer
# False    27574
# True        49
# Name: count, dtype: int64

# %%
elonmusk_tweets = pd.read_excel("../datasets/tweets/original/elonmusk_tweets.xlsx")
donald_trump_tweets = pd.read_csv("../datasets/tweets/original/donald_trump_tweets.csv", engine='python')
elonmusk_tweets, donald_trump_tweets
# Out:
# (      No  Event user_name      Date      Time  \
#  0    1.0    NaN  elonmusk  02.04.19  22:16:00
#  1    2.0    NaN  elonmusk  02.04.19  22:38:00
#  2    3.0    1.0  elonmusk  30.04.19  03:15:00
#  3    4.0    2.0  elonmusk  10.01.20  07:53:00
#  4    5.0    3.0  elonmusk  18.07.20  01:58:00
#  ..   ...    ...       ...       ...       ...
#  63  63.0   44.0  elonmusk  25.06.21  13:03:00
#  64  64.0   45.0  elonmusk  01.07.21  10:43:00
#  65  65.0    NaN  elonmusk  01.07.21  11:24:00
#  66  66.0   46.0  elonmusk  02.07.21  15:20:00
#  67  67.0   47.0  elonmusk  25.07.21  06:23:00
#
#                                                  Tweet  Coin Link Picture  \
#  0   Dogecoin rulz [picture of a doge with the capt...  DOGE   No     Yes
#  1   Dogecoin value may vary [link to an article en...  DOGE  Yes      No
#  2                                            Ethereum   ETH   No      No
#  3                       Bitcoin is *not* my safe word   BTC   No      No
# ...

# %%
elonmusk_tweets.Coin.value_counts()
# Out:
# Coin
# DOGE    45
# BTC     20
# ETH      1
# Name: count, dtype: int64

# %%
crypto_related = [ 'interest rates', 'interest', 'crypto', 'eth', 'coin', 'btc', 'ethereum', 'blockchain', \
                   'usa', 'united states', 'blockchain', 'cryptocurrency', 'doge', 'dogecoin', 'elon', 'nft', 'bitcoin', \
                   'centralised', 'decentralised', 'erc', 'ether', 'fiat', 'proof of', 'token'
                 ]

# %%
import re
filtered_df = donald_trump_tweets[donald_trump_tweets["text"].str.contains(r'|'.join([re.escape(word) for word in crypto_related]))]

# %%
filtered_df.to_csv("donald_trump_tweets_filtered.csv")

# %%
filtered_df = donald_trump_tweets[donald_trump_tweets["text"].str.lower().isin(crypto_related)]

# %%
filtered_df
# Out:
# Empty DataFrame
# Columns: [id, text, isRetweet, isDeleted, device, favorites, retweets, date, isFlagged]
# Index: []

# %%
donald_trump_tweets["text"].str.lower()
# Out:
# 0        republicans and democrats have both created ou...
# 1        i was thrilled to be back in the great city of...
# 2        rt @cbs_herridge: read: letter to surveillance...
# 3        the unsolicited mail in ballot scam is a major...
# 4        rt @mzhemingway: very friendly telling of even...
#                                ...
# 56566    rt @randpaul: i don’t know why @joebiden think...
# 56567    rt @elisestefanik: president @realdonaldtrump ...
# 56568    rt @teamtrump: live: presidential debate #deba...
# 56569    just signed an order to support the workers of...
# 56570    suburban women want safety &amp; security. joe...
# Name: text, Length: 56571, dtype: object

# %%
filtered_df = donald_trump_tweets[donald_trump_tweets["text"].str.contains(r'\b(?:' + '|'.join([re.escape(word) for word in crypto_related]) + r')\b')]
filtered_df.shape
# Out:
# (155, 9)

# %%
filtered_df.to_csv("donald_trump_2filtered.csv")

# %%
a = pd.read_csv("doge_tweets_filtered.csv")
a.drop(columns=['date', 'time', 'timezone', 'user_rt_id', 'user_rt', 'place', 'trans_src', 'trans_dest'], inplace=True)
a.rename(columns={'created_at':'date'}, inplace=True)
a.to_csv("doge_tweets_filtered.csv")
